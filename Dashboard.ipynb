# %%
! pip install dash
! pip install dash-core-components
! pip install dash-html-components
! pip install dash-renderer
! pip install statsmodels
# Out:
# Collecting dash
#   Downloading dash-2.9.3-py3-none-any.whl (10.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 95.8 MB/s eta 0:00:00
# Collecting dash-core-components==2.0.0
#   Downloading dash_core_components-2.0.0-py3-none-any.whl (3.8 kB)
# Collecting dash-table==5.0.0
#   Downloading dash_table-5.0.0-py3-none-any.whl (3.9 kB)
# Requirement already satisfied: plotly>=5.0.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from dash) (5.10.0)
# Collecting Flask>=1.0.4
#   Downloading Flask-2.3.2-py3-none-any.whl (96 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.9/96.9 KB 31.5 MB/s eta 0:00:00
# Collecting dash-html-components==2.0.0
#   Downloading dash_html_components-2.0.0-py3-none-any.whl (4.1 kB)
# Requirement already satisfied: importlib-metadata>=3.6.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from Flask>=1.0.4->dash) (5.0.0)
# Collecting itsdangerous>=2.1.2
#   Downloading itsdangerous-2.1.2-py3-none-any.whl (15 kB)
# Collecting Werkzeug>=2.3.3
#   Downloading Werkzeug-2.3.3-py3-none-any.whl (242 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 242.3/242.3 KB 23.6 MB/s eta 0:00:00
# Requirement already satisfied: click>=8.1.3 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from Flask>=1.0.4->dash) (8.1.3)
# Collecting Jinja2>=3.1.2
#   Downloading Jinja2-3.1.2-py3-none-any.whl (133 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.1/133.1 KB 41.5 MB/s eta 0:00:00
# Collecting blinker>=1.6.2
#   Downloading blinker-1.6.2-py3-none-any.whl (13 kB)
# Requirement already satisfied: tenacity>=6.2.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from plotly>=5.0.0->dash) (8.1.0)
# Requirement already satisfied: zipp>=0.5 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from importlib-metadata>=3.6.0->Flask>=1.0.4->dash) (3.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from Jinja2>=3.1.2->Flask>=1.0.4->dash) (2.0.0)
# Collecting MarkupSafe>=2.0
#   Downloading MarkupSafe-2.1.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (25 kB)
# Installing collected packages: dash-table, dash-html-components, dash-core-components, MarkupSafe, itsdangerous, blinker, Werkzeug, Jinja2, Flask, dash
#   Attempting uninstall: MarkupSafe
#     Found existing installation: MarkupSafe 2.0.0
#     Not uninstalling markupsafe at /shared-libs/python3.9/py-core/lib/python3.9/site-packages, outside environment /root/venv
#     Can't uninstall 'MarkupSafe'. No files were found to uninstall.
#   Attempting uninstall: Werkzeug
#     Found existing installation: Werkzeug 2.2.2
#     Not uninstalling werkzeug at /shared-libs/python3.9/py/lib/python3.9/site-packages, outside environment /root/venv
#     Can't uninstall 'Werkzeug'. No files were found to uninstall.
#   Attempting uninstall: Jinja2
#     Found existing installation: Jinja2 2.11.3
#     Not uninstalling jinja2 at /shared-libs/python3.9/py-core/lib/python3.9/site-packages, outside environment /root/venv
#     Can't uninstall 'Jinja2'. No files were found to uninstall.
# Successfully installed Flask-2.3.2 Jinja2-3.1.2 MarkupSafe-2.1.2 Werkzeug-2.3.3 blinker-1.6.2 dash-2.9.3 dash-core-components-2.0.0 dash-html-components-2.0.0 dash-table-5.0.0 itsdangerous-2.1.2
# WARNING: You are using pip version 22.0.4; however, version 23.1.2 is available.
# You should consider upgrading via the '/root/venv/bin/python -m pip install --upgrade pip' command.
# Requirement already satisfied: dash-core-components in /root/venv/lib/python3.9/site-packages (2.0.0)
# WARNING: You are using pip version 22.0.4; however, version 23.1.2 is available.
# You should consider upgrading via the '/root/venv/bin/python -m pip install --upgrade pip' command.
# Requirement already satisfied: dash-html-components in /root/venv/lib/python3.9/site-packages (2.0.0)
# WARNING: You are using pip version 22.0.4; however, version 23.1.2 is available.
# You should consider upgrading via the '/root/venv/bin/python -m pip install --upgrade pip' command.
# Collecting dash-renderer
#   Downloading dash_renderer-1.9.1.tar.gz (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 72.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: dash-renderer
#   Building wheel for dash-renderer (setup.py) ... done
#   Created wheel for dash-renderer: filename=dash_renderer-1.9.1-py3-none-any.whl size=1014875 sha256=1a8897344ed51bfb9068c0b06fccfbf3216ef71bceb84c20da21118b32cc5284
#   Stored in directory: /root/.cache/pip/wheels/52/2f/28/956ce9f7763c886d23f0082829bd726e5dacd6c708a5841c77
# Successfully built dash-renderer
# Installing collected packages: dash-renderer
# Successfully installed dash-renderer-1.9.1
# WARNING: You are using pip version 22.0.4; however, version 23.1.2 is available.
# You should consider upgrading via the '/root/venv/bin/python -m pip install --upgrade pip' command.
# Collecting statsmodels
#   Downloading statsmodels-0.13.5-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (9.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 138.1 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=21.3 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from statsmodels) (21.3)
# Collecting patsy>=0.5.2
#   Downloading patsy-0.5.3-py2.py3-none-any.whl (233 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.8/233.8 KB 42.5 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from statsmodels) (1.23.4)
# Requirement already satisfied: scipy>=1.3 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from statsmodels) (1.9.3)
# Requirement already satisfied: pandas>=0.25 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from statsmodels) (1.2.5)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from packaging>=21.3->statsmodels) (3.0.9)
# Requirement already satisfied: pytz>=2017.3 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from pandas>=0.25->statsmodels) (2022.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from pandas>=0.25->statsmodels) (2.8.2)
# Requirement already satisfied: six in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from patsy>=0.5.2->statsmodels) (1.16.0)
# Installing collected packages: patsy, statsmodels
# Successfully installed patsy-0.5.3 statsmodels-0.13.5
# WARNING: You are using pip version 22.0.4; however, version 23.1.2 is available.
# You should consider upgrading via the '/root/venv/bin/python -m pip install --upgrade pip' command.

# %%
import dash
from dash import dcc as dcc
from dash import html as html
import plotly.graph_objects as go
import pandas as pd
import numpy as np
import plotly.express as px
from sklearn.preprocessing import RobustScaler
from plotly.tools import make_subplots
from statsmodels.tsa.seasonal import seasonal_decompose
from datetime import datetime, timedelta

import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import GridSearchCV
# Out:
# 2023-05-03 09:10:02.567145: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-05-03 09:10:02.682587: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2023-05-03 09:10:02.682610: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2023-05-03 09:10:02.700216: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-05-03 09:10:04.047846: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2023-05-03 09:10:04.047919: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2023-05-03 09:10:04.047928: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
ccpiData = pd.read_csv('ccpi_m.csv')
ecpiData = pd.read_csv('ecpi_m.csv')
fcpiData = pd.read_csv('fcpi_m.csv')
hcpiData = pd.read_csv('hcpi_m.csv')
ppiData = pd.read_csv('ppi_m.csv')

# %%
ccpiCountryCodes = ccpiData[['IMF Country Code','Country Code','Country']]
ecpiCountryCodes = ecpiData[['IMF Country Code','Country Code','Country']]
fcpiCountryCodes = fcpiData[['IMF Country Code','Country Code','Country']]
hcpiCountryCodes = hcpiData[['IMF Country Code','Country Code','Country']]
ppiCountryCodes = ppiData[['IMF Country Code','Country Code','Country']]

# %%
ccpiCountryCodes.columns = [col + ' CCPI' for col in ccpiCountryCodes.columns]
ecpiCountryCodes.columns = [col + ' ECPI' for col in ecpiCountryCodes.columns]
fcpiCountryCodes.columns = [col + ' FCPI' for col in fcpiCountryCodes.columns]
hcpiCountryCodes.columns = [col + ' HCPI' for col in hcpiCountryCodes.columns]
ppiCountryCodes.columns = [col + ' PPI' for col in ppiCountryCodes.columns]

# %%
commonCountryCodes = ccpiCountryCodes.join(
    ecpiCountryCodes.set_index('IMF Country Code ECPI'), 
    on='IMF Country Code CCPI', how = 'inner').join(
        fcpiCountryCodes.set_index('IMF Country Code FCPI'), 
        on='IMF Country Code CCPI', how = 'inner').join(
            hcpiCountryCodes.set_index('IMF Country Code HCPI'),
             on='IMF Country Code CCPI', how = 'inner'
             ).join(ppiCountryCodes.set_index('IMF Country Code PPI'), 
             on='IMF Country Code CCPI', how = 'inner').drop_duplicates(
                 subset='IMF Country Code CCPI')

# %%
commonCountryCodesList = commonCountryCodes['Country Code CCPI'].tolist()
commonCountryNamesList = commonCountryCodes['Country CCPI'].tolist()

# %%
def segregate_train_test_data(data, window_size):
    X, y = [], []
    for i in range(window_size, len(data)):
        X.append(data[i-window_size:i])
        y.append(data[i])
    return np.array(X), np.array(y)

# %%
result = pd.read_csv('lstmHyperParameters.csv')
result.set_index('index', inplace=True)

# %%
result_dict = result.to_dict(orient='index')

# %%
if __name__ == '__main__':

    app = dash.Dash()

    def readCountryData(country_code):

        ccpiData = pd.read_csv('ccpi_m.csv')
        ecpiData = pd.read_csv('ecpi_m.csv')
        fcpiData = pd.read_csv('fcpi_m.csv')
        hcpiData = pd.read_csv('hcpi_m.csv')
        ppiData = pd.read_csv('ppi_m.csv')

        ccpiData = ccpiData[ccpiData['Country Code'] ==country_code].iloc[:,4:-1]
        ecpiData = ecpiData[ecpiData['Country Code'] ==country_code].iloc[:,4:-1]
        fcpiData = fcpiData[fcpiData['Country Code'] ==country_code].iloc[:,4:-1]
        hcpiData = hcpiData[hcpiData['Country Code'] ==country_code].iloc[:,4:-1]
        ppiData = ppiData[ppiData['Country Code'] ==country_code].iloc[:,4:-1]

        rawDF = pd.concat([ccpiData, ecpiData, fcpiData, hcpiData, ppiData])
        rawDF = rawDF.T
        rawDF.rename(columns=rawDF.iloc[0,:], inplace = True)
        rawDF = rawDF.tail(-1)
        rawDF.drop(rawDF.tail(1).index,inplace=True)
        time = pd.DatetimeIndex([i[:-2]+'-'+i[-2:] for i in rawDF.index])
        rawDF = rawDF.set_index(time)
        df = rawDF.fillna(method='ffill').fillna(method='bfill')

        dataGreaterthan2003 = df[df.index >= '2003-01-01']
        return dataGreaterthan2003

    structureDF = readCountryData('ALB')
    
    countryCodeDropdown = html.Div([dcc.Dropdown(
        id='country-selection-dropdown',
        options=[{'label': i, 'value': j} for i, j in zip(commonCountryNamesList, commonCountryCodesList)],
        value=commonCountryCodesList[0]
        )])
    displayCountryName = html.Div(id='country-selected')
    displaySelectedMonth = html.Div(id='world-map-month-selected')
    displayPredictionMonths = html.Div(id='prediction-months-selected')
    precisionDropdown =  html.Div([
        dcc.Dropdown(
            id='precision-selection-dropdown',
            options=[
                {'label': 'Low', 'value': 'low'},
                {'label': 'Medium', 'value': 'medium'},
                {'label': 'High', 'value': 'high'}
            ],
            value='low',
            style={
                'width': '25%',
                'margin': 'auto'
            }
        )
    ], style={
        'display': 'flex',
        'justify-content': 'center',
        'align-items': 'center'
    })

    @app.callback(dash.dependencies.Output('country-selected', 'children'),
                dash.dependencies.Input('country-selection-dropdown', 'value'))
    def update_output(value):
        country_code = value
        return html.H3('Country Selected is : ' + commonCountryNamesList[commonCountryCodesList.index(country_code)],
            style={'textAlign': 'center',
                    'color': '#000205'}
            )

    @app.callback(dash.dependencies.Output('line-plot', 'figure'),
                [dash.dependencies.Input('year-range-slider-line-plot', 'value'), 
                 dash.dependencies.Input('country-selection-dropdown', 'value')])
    def update_line_plot(year_range, value):
        country_code = value
        df = readCountryData(country_code)

        df_robust = df.copy()
        # apply robust scaling
        for column in df_robust.columns:
            df_robust[column] = (df_robust[column] - df_robust[column].median())  / (df_robust[column].quantile(0.75) - df_robust[column].quantile(0.25))

        df = df_robust
        
        # filter the DataFrame by the selected year range
        filtered_df = df[(df.index.year >= year_range[0]) & (df.index.year <= year_range[1])]
        
        df = filtered_df
        
        # Create a line plot of the dataframe using go.Scatter for each column
        fig = go.Figure()
        for col in df.columns:
            fig.add_trace(go.Scatter(x=df.index, y=df[col], mode='lines', name=col))

        # Set the layout for the plot
        fig.update_layout(title='Line Plot of inflation indices',
                        xaxis_title='Year', yaxis_title='Value')
        
        return fig    

    @app.callback(dash.dependencies.Output('histogram', 'figure'),
                [dash.dependencies.Input('year-range-slider-histogram', 'value'), 
                 dash.dependencies.Input('country-selection-dropdown', 'value')])
    def update_histogram(year_range, value):
        country_code = value
        df = readCountryData(country_code)

        df_robust = df.copy()
        # apply robust scaling
        for column in df_robust.columns:
            df_robust[column] = (df_robust[column] - df_robust[column].median())  / (df_robust[column].quantile(0.75) - df_robust[column].quantile(0.25))

        df = df_robust
        
        # filter the DataFrame by the selected year range
        filtered_df = df[(df.index.year >= year_range[0]) & (df.index.year <= year_range[1])]
        
        traces = []
        for col in filtered_df.columns:
            trace = go.Histogram(x=filtered_df[col], name=col, opacity=0.3, nbinsx=30)
            traces.append(trace)
        
        layout = go.Layout(title='Histogram plot of inflation indices',barmode='overlay')
        
        fig = go.Figure(data=traces, layout=layout)
        
        return fig
   
    @app.callback(dash.dependencies.Output('inflation-violin-plot', 'figure'),
                [dash.dependencies.Input('year-range-slider-violin', 'value'), 
                 dash.dependencies.Input('country-selection-dropdown', 'value')])
    def update_violin_plot(year_range, value):
        
        country_code = value
        df = readCountryData(country_code)

        df_robust = df.copy()
        # apply robust scaling
        for column in df_robust.columns:
            df_robust[column] = (df_robust[column] - df_robust[column].median())  / (df_robust[column].quantile(0.75) - df_robust[column].quantile(0.25))

        df = df_robust
    
        # filter the DataFrame by the selected year range
        filtered_df = df[(df.index.year >= year_range[0]) & (df.index.year <= year_range[1])]
        # create a list of violin traces for each column
        traces = [go.Violin(y=filtered_df[col], name=col) for col in filtered_df.columns]
        # create the figure object and return it
        fig = go.Figure(data=traces)
        fig.update_layout(title='Inflation Indices Violin Plots for Selected Year Range')
        return fig

    @app.callback(dash.dependencies.Output('pair-plot', 'figure'),
                [dash.dependencies.Input('year-range-slider-pair-plot', 'value'), 
                 dash.dependencies.Input('country-selection-dropdown', 'value')])
    def update_pair_plot(year_range, value):
        country_code = value
        df = readCountryData(country_code)

        df_robust = df.copy()
        # apply robust scaling
        for column in df_robust.columns:
            df_robust[column] = (df_robust[column] - df_robust[column].median())  / (df_robust[column].quantile(0.75) - df_robust[column].quantile(0.25))

        df = df_robust
        
        # filter the DataFrame by the selected year range
        filtered_df = df[(df.index.year >= year_range[0]) & (df.index.year <= year_range[1])]
        
        df = filtered_df
        
        fig = make_subplots(rows=len(df.columns), cols=len(df.columns), shared_xaxes=False, shared_yaxes=False)

        for i in range(len(df.columns)):
            for j in range(len(df.columns)):
                scatter_trace = go.Scatter(
                    x=df.iloc[:, i],
                    y=df.iloc[:, j],
                    mode='markers',
                    showlegend=False
                )
                hist_trace = go.Histogram(
                    x=df.iloc[:, i],
                    nbinsx=30,
                    showlegend=False
                )
                if i == j:
                    fig.add_trace(hist_trace, row=i+1, col=j+1)
                    fig.update_xaxes(title_text=df.columns[i].replace(' Price Index',''), row=i+1, col=j+1, tickfont=dict(size=7))
                    fig.update_yaxes(title_text=df.columns[j].replace(' Price Index',''), row=i+1, col=j+1, tickfont=dict(size=7))
                else:
                    fig.add_trace(scatter_trace, row=i+1, col=j+1)
                    fig.update_xaxes(title_text=df.columns[i].replace(' Price Index',''), row=i+1, col=j+1, tickfont=dict(size=7))
                    fig.update_yaxes(title_text=df.columns[j].replace(' Price Index',''), row=i+1, col=j+1, tickfont=dict(size=7))

        fig.update_layout(height=1300, width=1300, title='Pair plot of inflation indices')
        
        return fig

    @app.callback(dash.dependencies.Output('time-series-decomposition-plot', 'figure'),
                [dash.dependencies.Input('time-series-decomposition-radio-buttons', 'value'),
                 dash.dependencies.Input('year-range-slider-time-series-decomposition', 'value'), 
                 dash.dependencies.Input('country-selection-dropdown', 'value')])
    def update_time_series_decomposition_plot(selected_index, year_range, value):
        
        country_code = value
        df = readCountryData(country_code)

        df_robust = df.copy()
        # apply robust scaling
        for column in df_robust.columns:
            df_robust[column] = (df_robust[column] - df_robust[column].median())  / (df_robust[column].quantile(0.75) - df_robust[column].quantile(0.25))

        df = df_robust
        
        # filter the DataFrame by the selected year range
        filtered_df = df[(df.index.year >= year_range[0]) & (df.index.year <= year_range[1])]
        
        df = filtered_df
        
        time_series_decomposition = seasonal_decompose(x=df[selected_index], model='additive', period=12)
        trend_decomposition = time_series_decomposition.trend
        seasonal_decomposition = time_series_decomposition.seasonal
        residual_decomposition = time_series_decomposition.resid
        
        fig = make_subplots(rows=4, 
                            cols=1, 
                            shared_xaxes=False, 
                            shared_yaxes=False, 
                            subplot_titles=(
                                selected_index, 
                                selected_index  + ' Trend', 
                                selected_index + ' Seasonal', 
                                selected_index + ' Residual'))
        
        fig.add_trace(go.Scatter(x=df.index, y=df[selected_index], mode='lines', name=selected_index, showlegend=False), row = 1, col = 1)

        fig.add_trace(go.Scatter(x=df.index, y=trend_decomposition, mode='lines', name=selected_index + ' Trend', showlegend=False), row = 2, col = 1)

        fig.add_trace(go.Scatter(x=df.index, y=seasonal_decomposition, mode='lines', name=selected_index + ' Seasonal', showlegend=False), row = 3, col = 1)

        fig.add_trace(go.Scatter(x=df.index, y=residual_decomposition, mode='lines', name=selected_index + ' Residual', showlegend=False), row = 4, col = 1)
        
        fig.update_layout(height=800, width=1300, title='Time Series Decomposition plot of inflation indices')
        
        return fig
    
    @app.callback(dash.dependencies.Output('world-map-month-selected', 'children'),
                dash.dependencies.Input('world-map-month-picker', 'date'))
    def update_selected_month_output(value):
        date = value
        month = pd.to_datetime(date).strftime('%B')
        year = pd.to_datetime(date).year
        return html.H4('Month selected : ' + str(month) + ' ' + str(year),
            style={'textAlign': 'center',
                    'color': '#000205'}
            )

    @app.callback(
        dash.dependencies.Output('world-map-inflation-index', 'figure'),
        [dash.dependencies.Input('world-map-month-picker', 'date'),
         dash.dependencies.Input('world-map-radio-buttons', 'value')]
    )
    def update_world_map(date, selected_index):
        
        month = str(pd.to_datetime(date).strftime("%m"))
        year = str(pd.to_datetime(date).year)
        
        column_name = str(year) + str(month)
        
        if selected_index == 'Official Core Consumer Price Index':
            ccpiData = pd.read_csv('ccpi_m.csv')
            ccpiData = ccpiData[['Country Code', 'Country', column_name]]
            df = ccpiData
        elif selected_index == 'Energy Price Index':
            ecpiData = pd.read_csv('ecpi_m.csv')
            ecpiData = ecpiData[['Country Code', 'Country', column_name]]
            df = ecpiData
        elif selected_index == 'Food Price Index':
            fcpiData = pd.read_csv('fcpi_m.csv')
            fcpiData = fcpiData[['Country Code', 'Country', column_name]]
            df = fcpiData
        elif selected_index == 'Headline Consumer Price Index':
            hcpiData = pd.read_csv('hcpi_m.csv')
            hcpiData = hcpiData[['Country Code', 'Country', column_name]]
            df = hcpiData
        else:
            ppiData = pd.read_csv('ppi_m.csv')
            ppiData = ppiData[['Country Code', 'Country', column_name]]
            df = ppiData
            
        df[column_name] = np.log(df[column_name])
               
        fig = px.choropleth(df, locations='Country', 
                            locationmode='country names', 
                            color=column_name,
                            color_continuous_scale='Viridis',
                            range_color=[df[column_name].min(), df[column_name].max()],
                            color_continuous_midpoint=df[column_name].median(),
                            projection='orthographic')
        
        #fig.update_layout(autosize=True)
        fig.update_layout(height=700, width=1200, autosize=True)
        
        return fig
    
    @app.callback(
        dash.dependencies.Output('prediction-months-selected', 'children'),
        dash.dependencies.Input('prediction-month-picker', 'start_date'),
        dash.dependencies.Input('prediction-month-picker', 'end_date'),
        dash.dependencies.Input('precision-selection-dropdown','value')
    )
    def update_prediction_months_output(start_date, end_date, precision):
        
        start_month = pd.to_datetime(start_date).strftime('%B')
        start_year = pd.to_datetime(start_date).year

        end_month = pd.to_datetime(end_date).strftime('%B')
        end_year = pd.to_datetime(end_date).year
        return html.H4('Start Month : ' + str(start_month) + ' ' + str(start_year) + ', End Month : ' + str(end_month) + ' ' + str(end_year) + ', Precision : ' + precision,
            style={'textAlign': 'center',
                    'color': '#000205'}
            )
    
    @app.callback(
        dash.dependencies.Output('inflation-index-prediction', 'figure'),
        [dash.dependencies.Input('prediction-month-picker', 'start_date'),
        dash.dependencies.Input('prediction-month-picker', 'end_date'),
        dash.dependencies.Input('prediction-radio-buttons', 'value'),
        dash.dependencies.Input('precision-selection-dropdown','value'),
        dash.dependencies.Input('country-selection-dropdown', 'value')]
    )
    def update_prediction_months_output(start_date, end_date, index, precision, country_code):

        df = readCountryData(country_code)

        # select the 'values' column
        values_col = df[index]

        # calculate the median and quartiles of the column
        median = values_col.median()
        q25 = values_col.quantile(0.25)
        q75 = values_col.quantile(0.75)

        # apply the formula to normalize the values
        values_col = (values_col - median) / (q75 - q25)

        # update the column in the original dataframe
        df[index] = values_col

        test_size = 12

        #test sets
        lstmTestDF = df.tail(12)

        # train sets
        # get the number of rows in the dataframe
        num_rows = df.shape[0]

        # get all rows except the last 12 rows
        lstmTrainDF = df.iloc[:num_rows-12, :]

        X_train_dict = {}
        y_train_dict = {}
        X_test_dict = {}
        y_test_dict = {}
        window = 3

        col = index

        X_train_dict[col], y_train_dict[col] = segregate_train_test_data(data=lstmTrainDF[col], window_size=window)
        X_test_dict[col], y_test_dict[col] = segregate_train_test_data(data=lstmTestDF[col], window_size=window)
        X_train_dict[col] = np.reshape(X_train_dict[col], (X_train_dict[col].shape[0], X_train_dict[col].shape[1], 1))
        X_test_dict[col] = np.reshape(X_test_dict[col], (X_test_dict[col].shape[0], X_test_dict[col].shape[1], 1))
            
        X_dict = {}
        y_dict = {}
  
        X_dict[col], y_dict[col] = segregate_train_test_data(data=lstmTrainDF[col], window_size=3)
        X_dict[col] = np.reshape(X_dict[col], (X_dict[col].shape[0], X_dict[col].shape[1], 1))   
        
        learning_rate = result_dict[col]['learning_rate']
        epochs = result_dict[col]['epochs']

        def create_lstm_model_implementation(col, learning_rate, epochs):
            model = Sequential()
            model.add(LSTM(64, input_shape=(X_train_dict[col].shape[1], X_train_dict[col].shape[2])))
            model.add(Dense(1))
            optimizer = Adam(learning_rate=learning_rate)
            model.compile(loss='mse', optimizer=optimizer)
            model.fit(X_train_dict[col], y_train_dict[col], epochs=epochs, batch_size=64, validation_data=(X_test_dict[col], y_test_dict[col]))
            return model

        if (precision == 'low'):
            model = create_lstm_model_implementation(col= col,learning_rate=learning_rate ,epochs=epochs)
        elif (precision == 'medium'):
            model = create_lstm_model_implementation(col= col,learning_rate=learning_rate / 5 ,epochs=epochs * 5)
        else:
            model = create_lstm_model_implementation(col= col,learning_rate=learning_rate / 10 ,epochs=epochs * 10)

        predictions = model.predict(X_test_dict[col])

        start_date = pd.to_datetime(start_date)
        end_date = pd.to_datetime(end_date) 

        # make predictions for future values
        future_dates = pd.date_range(start_date,end_date, freq='MS')
        future_values = []
        last_data = df[[col]].tail(3)

        for i in range(len(future_dates)):
            X = np.expand_dims(last_data, axis=0)
            y_pred = model.predict(X)[0][0]
            future_values.append(y_pred)
            last_data = np.vstack((last_data[1:], [y_pred]))

        future_data = pd.DataFrame(future_values, columns= ['prediction'], index=future_dates)

        actual_trace = go.Scatter(x=df.index, y=df[col], mode='lines', name='Actual')
        prediction_trace = go.Scatter(x=future_data.index, y=future_data['prediction'], mode='lines', name='Prediction')

        layout = go.Layout(title='Inflation indices prediction',
                            xaxis=dict(title='Date'),
                            yaxis=dict(title='Value'))

        fig = go.Figure(data=[actual_trace, prediction_trace], layout=layout)


        return fig

    app.layout = html.Div([
    html.H1(children='Current Topics In Data Science',
            style={'textAlign': 'center',
                    'color': '#000205'}
            ),
    html.Br(),
    countryCodeDropdown,
    displayCountryName,
    html.Hr(),
    html.H4(children='Select year range to view Line Plot plots for Inflation indices',
            style={'textAlign': 'center',
                    'color': '#000205'}
            ),
    dcc.RangeSlider(
        id='year-range-slider-line-plot',
        min=structureDF.index.year.min(),
        max=structureDF.index.year.max(),
        step=1,
        marks={year: str(year) for year in structureDF.index.year.unique()},
        value=[structureDF.index.year.min(), structureDF.index.year.max()]
    ),
    html.Div([
    dcc.Loading(id="loading-icon-line-plot", children=[
        dcc.Graph(id='line-plot')
    ], type="circle")
    ]),
    #dcc.Graph(id='line-plot'),
    html.Hr(),
    html.H4(children='Select year range to view Histogram plots for Inflation indices',
            style={'textAlign': 'center',
                    'color': '#000205'}
            ),
    dcc.RangeSlider(
        id='year-range-slider-histogram',
        min=structureDF.index.year.min(),
        max=structureDF.index.year.max(),
        step=1,
        marks={year: str(year) for year in structureDF.index.year.unique()},
        value=[structureDF.index.year.min(), structureDF.index.year.max()]
    ),
    html.Div([
    dcc.Loading(id="loading-icon-histogram", children=[
        dcc.Graph(id='histogram')
    ], type="circle")
    ]),
    #dcc.Graph(id='histogram'),
    html.Hr(),
    html.H4(children='Select year range to view violin plots for Inflation indices',
            style={'textAlign': 'center',
                    'color': '#000205'}
            ),
    dcc.RangeSlider(
        id='year-range-slider-violin',
        min=structureDF.index.year.min(),
        max=structureDF.index.year.max(),
        step=1,
        marks={year: str(year) for year in structureDF.index.year.unique()},
        value=[structureDF.index.year.min(), structureDF.index.year.max()]
    ),
    html.Div([
    dcc.Loading(id="loading-icon-inflation-violin-plot", children=[
        dcc.Graph(id='inflation-violin-plot')
    ], type="circle")
    ]),
    #dcc.Graph(id='inflation-violin-plot'),
    html.Hr(),
    html.H4(children='Select year range to view pair plots for Inflation indices',
            style={'textAlign': 'center',
                    'color': '#000205'}
            ),
    dcc.RangeSlider(
        id='year-range-slider-pair-plot',
        min=structureDF.index.year.min(),
        max=structureDF.index.year.max(),
        step=1,
        marks={year: str(year) for year in structureDF.index.year.unique()},
        value=[structureDF.index.year.min(), structureDF.index.year.max()]
    ),
    html.Div([
    dcc.Loading(id="loading-icon-pair-plot", children=[
        dcc.Graph(id='pair-plot')
    ], type="circle")
    ]),
    #dcc.Graph(id='pair-plot'),
    html.Hr(),
    html.Div([
            html.H4('Select index to Display:'),
            dcc.RadioItems(
                id='time-series-decomposition-radio-buttons',
                options=[
                    {'label': 'Official Core Consumer Price Index', 'value': 'Official Core Consumer Price Index'},
                    {'label': 'Energy Price Index', 'value': 'Energy Price Index'},
                    {'label': 'Food Price Index', 'value': 'Food Price Index'},
                    {'label': 'Headline Consumer Price Index', 'value': 'Headline Consumer Price Index'},
                    {'label': 'Producer Price Index', 'value': 'Producer Price Index'},
                ],
                value='Official Core Consumer Price Index'
            ),
        ], style={'textAlign': 'center'}),
    html.H4(children='Select year range to view time-series decomposition plots for Inflation indices',
            style={'textAlign': 'center',
                    'color': '#000205'}
            ),
    dcc.RangeSlider(
        id='year-range-slider-time-series-decomposition',
        min=structureDF.index.year.min(),
        max=structureDF.index.year.max(),
        step=1,
        marks={year: str(year) for year in structureDF.index.year.unique()},
        value=[structureDF.index.year.min(), structureDF.index.year.max()]
    ),
    html.Div([
    dcc.Loading(id="loading-icon-time-series-decomposition-plot", children=[
        dcc.Graph(id='time-series-decomposition-plot')
    ], type="circle")
    ]),
    #dcc.Graph(id='time-series-decomposition-plot'),
    html.Hr(),
    html.H4(children='Select a month to view Inflation indices for available countries',
            style={'textAlign': 'center',
                    'color': '#000205'}
            ),
    html.Div(
        dcc.DatePickerSingle(
            id='world-map-month-picker',
            date=structureDF.index.max(),
            clearable=True,
            with_portal=True,
            min_date_allowed=structureDF.index.min(),
            max_date_allowed=structureDF.index.max(),
            display_format='MMM Y'
        ), style={'textAlign': 'center',
                    'color': '#000205'}
    ),
    html.Div([
            html.H4('Select index to Display:'),
            dcc.RadioItems(
                id='world-map-radio-buttons',
                options=[
                    {'label': 'Official Core Consumer Price Index', 'value': 'Official Core Consumer Price Index'},
                    {'label': 'Energy Price Index', 'value': 'Energy Price Index'},
                    {'label': 'Food Price Index', 'value': 'Food Price Index'},
                    {'label': 'Headline Consumer Price Index', 'value': 'Headline Consumer Price Index'},
                    {'label': 'Producer Price Index', 'value': 'Producer Price Index'},
                ],
                value='Official Core Consumer Price Index'
            ),
        ], style={'textAlign': 'center'}),
    displaySelectedMonth,
    html.Div([
    dcc.Loading(id="loading-icon-world-map-inflation-index", children=[
        dcc.Graph(id='world-map-inflation-index')
    ], type="circle")
    ]),
    #dcc.Graph(id='world-map-inflation-index'),
    html.Hr(),
    html.H3(children='Inflation predictions',
            style={'textAlign': 'center',
                    'color': '#000205'}
            ),
    html.Div([
        html.H4('Select index to Display:'),
        dcc.RadioItems(
            id='prediction-radio-buttons',
            options=[
                {'label': 'Official Core Consumer Price Index', 'value': 'Official Core Consumer Price Index'},
                {'label': 'Energy Price Index', 'value': 'Energy Price Index'},
                {'label': 'Food Price Index', 'value': 'Food Price Index'},
                {'label': 'Headline Consumer Price Index', 'value': 'Headline Consumer Price Index'},
                {'label': 'Producer Price Index', 'value': 'Producer Price Index'},
            ],
            value='Official Core Consumer Price Index'
        ),
    ], style={'textAlign': 'center'}),
    html.Div([
        html.H4('Select Start and End months:'),
        dcc.DatePickerRange(
            id='prediction-month-picker',
            start_date_placeholder_text="Start Period",
            end_date_placeholder_text="End Period",
            clearable=True,
            with_portal=True,
            min_date_allowed=structureDF.index.max(),
            max_date_allowed=structureDF.index.max()+ timedelta(days=5*365),
            display_format='MMM Y'
    )], style={'textAlign': 'center',
                    'color': '#000205'}
    ),
    html.H4(children='Select precision level:',
                style={'textAlign': 'center'}
        ),
    precisionDropdown,
    displayPredictionMonths,
    dcc.Loading(
        id="loading-inflation-index-prediction",
        children=dcc.Graph(
            id='inflation-index-prediction',
            figure={}
        ),
        type="circle",
    ),
    html.Hr()
    ])
    app.run(host='0.0.0.0', port=8080)
# Out:
# Dash is running on http://0.0.0.0:8080/
#
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:8080
#  * Running on http://172.3.165.178:8080
# Press CTRL+C to quit
# 172.3.18.60 - - [03/May/2023 09:10:13] "GET / HTTP/1.1" 200 -
# 172.3.18.60 - - [03/May/2023 09:10:13] "GET /_dash-component-suites/dash/deps/polyfill@7.v2_9_3m1683104985.12.1.min.js HTTP/1.1" 200 -
# 172.3.18.60 - - [03/May/2023 09:10:13] "GET /_dash-component-suites/dash/dash-renderer/build/dash_renderer.v2_9_3m1683104985.min.js HTTP/1.1" 200 -
# 172.3.22.214 - - [03/May/2023 09:10:13] "GET /_dash-component-suites/dash/dcc/dash_core_components.v2_9_2m1683104985.js HTTP/1.1" 200 -
# 172.3.22.214 - - [03/May/2023 09:10:13] "GET /_dash-component-suites/dash/deps/react@16.v2_9_3m1683104985.14.0.min.js HTTP/1.1" 200 -
# 172.3.18.60 - - [03/May/2023 09:10:13] "GET /_dash-component-suites/dash/deps/react-dom@16.v2_9_3m1683104985.14.0.min.js HTTP/1.1" 200 -
# 172.3.150.40 - - [03/May/2023 09:10:13] "GET /_dash-component-suites/dash/deps/prop-types@15.v2_9_3m1683104985.8.1.min.js HTTP/1.1" 200 -
# 172.3.18.60 - - [03/May/2023 09:10:13] "GET /_dash-component-suites/dash/html/dash_html_components.v2_0_11m1683104985.min.js HTTP/1.1" 200 -
# 172.3.18.60 - - [03/May/2023 09:10:13] "GET /_dash-component-suites/dash/dash_table/bundle.v5_2_4m1683104985.js HTTP/1.1" 200 -
# 172.3.150.40 - - [03/May/2023 09:10:13] "GET /_dash-component-suites/dash/dcc/dash_core_components-shared.v2_9_2m1683104985.js HTTP/1.1" 200 -
# 172.3.150.40 - - [03/May/2023 09:10:14] "GET /_dash-dependencies HTTP/1.1" 200 -
# 172.3.22.214 - - [03/May/2023 09:10:14] "GET /_dash-layout HTTP/1.1" 200 -
# 172.3.150.40 - - [03/May/2023 09:10:14] "GET /_favicon.ico?v=2.9.3 HTTP/1.1" 200 -
# 172.3.18.60 - - [03/May/2023 09:10:14] "GET /_dash-component-suites/dash/dcc/async-dropdown.js HTTP/1.1" 200 -
# 172.3.150.40 - - [03/May/2023 09:10:14] "GET /_dash-component-suites/dash/dcc/async-slider.js HTTP/1.1" 200 -
# 172.3.22.214 - - [03/May/2023 09:10:14] "GET /_dash-component-suites/dash/dcc/async-graph.js HTTP/1.1" 200 -
# 172.3.22.214 - - [03/May/2023 09:10:14] "GET /_dash-component-suites/dash/dcc/async-plotlyjs.js HTTP/1.1" 200 -
# 172.3.150.40 - - [03/May/2023 09:10:14] "GET /_dash-component-suites/dash/dcc/async-datepicker.js HTTP/1.1" 200 -
# 172.3.150.40 - - [03/May/2023 09:10:15] "GET /_favicon.ico?v=2.9.3 HTTP/1.1" 200 -
# 172.3.18.60 - - [03/May/2023 09:10:15] "POST /_dash-update-component HTTP/1.1" 200 -
# 172.3.22.214 - - [03/May/2023 09:10:15] "POST /_dash-update-component HTTP/1.1" 200 -
# [2023-05-03 09:10:15,101] ERROR in app: Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/root/venv/lib/python3.9/site-packages/flask/app.py", line 2190, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/root/venv/lib/python3.9/site-packages/flask/app.py", line 1486, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/root/venv/lib/python3.9/site-packages/flask/app.py", line 1484, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/root/venv/lib/python3.9/site-packages/flask/app.py", line 1469, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#   File "/root/venv/lib/python3.9/site-packages/dash/dash.py", line 1283, in dispatch
#     ctx.run(
#   File "/root/venv/lib/python3.9/site-packages/dash/_callback.py", line 450, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "/tmp/ipykernel_127/1041133795.py", line 314, in update_prediction_months_output
#     start_month = pd.to_datetime(start_date).strftime('%B')
# AttributeError: 'NoneType' object has no attribute 'strftime'
# 172.3.22.214 - - [03/May/2023 09:10:15] "POST /_dash-update-component HTTP/1.1" 500 -
# 172.3.22.214 - - [03/May/2023 09:10:19] "POST /_dash-update-component HTTP/1.1" 200 -
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File pandas/_libs/hashtable_class_helper.pxi:4588, in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# File /shared-libs/python3.9/py/lib/python3.9/site-packages/pandas/core/generic.py:1785, in NDFrame.__hash__(self)
#    1784 def __hash__(self) -> int:
# -> 1785     raise TypeError(
#    1786         f"{repr(type(self).__name__)} objects are mutable, "
#    1787         f"thus they cannot be hashed"
#    1788     )
#
# TypeError: 'Series' objects are mutable, thus they cannot be hashed
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File pandas/_libs/hashtable_class_helper.pxi:4588, in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# File /shared-libs/python3.9/py/lib/python3.9/site-packages/pandas/core/generic.py:1785, in NDFrame.__hash__(self)
#    1784 def __hash__(self) -> int:
# -> 1785     raise TypeError(
#    1786         f"{repr(type(self).__name__)} objects are mutable, "
#    1787         f"thus they cannot be hashed"
#    1788     )
#
# TypeError: 'Series' objects are mutable, thus they cannot be hashed
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas/_libs/hashtable_class_helper.pxi", line 4588, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas/_libs/hashtable_class_helper.pxi", line 4588, in pandas._libs.hashtable.PyObjectHashTable.map_locations
#   File "/shared-libs/python3.9/py/lib/python3.9/site-packages/pandas/core/generic.py", line 1785, in __hash__
#   File "/shared-libs/python3.9/py/lib/python3.9/site-packages/pandas/core/generic.py", line 1785, in __hash__
#     raise TypeError(
# TypeError: 'Series' objects are mutable, thus they cannot be hashed
#     raise TypeError(
# TypeError: 'Series' objects are mutable, thus they cannot be hashed
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File pandas/_libs/hashtable_class_helper.pxi:4588, in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# File /shared-libs/python3.9/py/lib/python3.9/site-packages/pandas/core/generic.py:1785, in NDFrame.__hash__(self)
#    1784 def __hash__(self) -> int:
# -> 1785     raise TypeError(
#    1786         f"{repr(type(self).__name__)} objects are mutable, "
#    1787         f"thus they cannot be hashed"
#    1788     )
#
# TypeError: 'Series' objects are mutable, thus they cannot be hashed
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File pandas/_libs/hashtable_class_helper.pxi:4588, in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# File /shared-libs/python3.9/py/lib/python3.9/site-packages/pandas/core/generic.py:1785, in NDFrame.__hash__(self)
#    1784 def __hash__(self) -> int:
# -> 1785     raise TypeError(
#    1786         f"{repr(type(self).__name__)} objects are mutable, "
#    1787         f"thus they cannot be hashed"
#    1788     )
#
# TypeError: 'Series' objects are mutable, thus they cannot be hashed
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas/_libs/hashtable_class_helper.pxi", line 4588, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas/_libs/hashtable_class_helper.pxi", line 4588, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# [2023-05-03 09:10:21,219] ERROR in app: Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/root/venv/lib/python3.9/site-packages/flask/app.py", line 2190, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/root/venv/lib/python3.9/site-packages/flask/app.py", line 1486, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/root/venv/lib/python3.9/site-packages/flask/app.py", line 1484, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/root/venv/lib/python3.9/site-packages/flask/app.py", line 1469, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#   File "/root/venv/lib/python3.9/site-packages/dash/dash.py", line 1283, in dispatch
#     ctx.run(
#   File "/root/venv/lib/python3.9/site-packages/dash/_callback.py", line 450, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "/tmp/ipykernel_127/1041133795.py", line 80, in update_line_plot
#     df_robust[column] = (df_robust[column] - df_robust[column].median())  / (df_robust[column].quantile(0.75) - df_robust[column].quantile(0.25))
#   File "/shared-libs/python3.9/py/lib/python3.9/site-packages/pandas/core/frame.py", line 3024, in __getitem__
#     indexer = self.columns.get_loc(key)
#   File "/shared-libs/python3.9/py/lib/python3.9/site-packages/pandas/core/indexes/base.py", line 3081, in get_loc
#     return self._engine.get_loc(casted_key)
#   File "pandas/_libs/index.pyx", line 70, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas/_libs/index.pyx", line 96, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas/_libs/index.pyx", line 109, in pandas._libs.index.IndexEngine._get_loc_duplicates
#   File "pandas/_libs/index.pyx", line 176, in pandas._libs.index.IndexEngine.is_monotonic_increasing.__get__
#   File "pandas/_libs/index.pyx", line 193, in pandas._libs.index.IndexEngine._do_monotonic_check
#   File "pandas/_libs/index.pyx", line 210, in pandas._libs.index.IndexEngine._call_monotonic
#   File "pandas/_libs/algos.pyx", line 760, in pandas._libs.algos.is_monotonic
#   File "/shared-libs/python3.9/py/lib/python3.9/site-packages/pandas/core/generic.py", line 1442, in __nonzero__
#     raise ValueError(
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
#   File "/shared-libs/python3.9/py/lib/python3.9/site-packages/pandas/core/generic.py", line 1785, in __hash__
# 172.3.150.40 - - [03/May/2023 09:10:21] "POST /_dash-update-component HTTP/1.1" 500 -
#   File "/shared-libs/python3.9/py/lib/python3.9/site-packages/pandas/core/generic.py", line 1785, in __hash__
#     raise TypeError(
# TypeError: 'Series' objects are mutable, thus they cannot be hashed
#     raise TypeError(
# TypeError: 'Series' objects are mutable, thus they cannot be hashed
# [2023-05-03 09:10:21,219] ERROR in app: Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/root/venv/lib/python3.9/site-packages/flask/app.py", line 2190, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/root/venv/lib/python3.9/site-packages/flask/app.py", line 1486, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/root/venv/lib/python3.9/site-packages/flask/app.py", line 1484, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/root/venv/lib/python3.9/site-packages/flask/app.py", line 1469, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#   File "/root/venv/lib/python3.9/site-packages/dash/dash.py", line 1283, in dispatch
#     ctx.run(
#   File "/root/venv/lib/python3.9/site-packages/dash/_callback.py", line 450, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "/tmp/ipykernel_127/1041133795.py", line 162, in update_pair_plot
#     df_robust[column] = (df_robust[column] - df_robust[column].median())  / (df_robust[column].quantile(0.75) - df_robust[column].quantile(0.25))
#   File "/shared-libs/python3.9/py/lib/python3.9/site-packages/pandas/core/frame.py", line 3024, in __getitem__
#     indexer = self.columns.get_loc(key)
#   File "/shared-libs/python3.9/py/lib/python3.9/site-packages/pandas/core/indexes/base.py", line 3081, in get_loc
#     return self._engine.get_loc(casted_key)
#   File "pandas/_libs/index.pyx", line 70, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas/_libs/index.pyx", line 96, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas/_libs/index.pyx", line 109, in pandas._libs.index.IndexEngine._get_loc_duplicates
#   File "pandas/_libs/index.pyx", line 176, in pandas._libs.index.IndexEngine.is_monotonic_increasing.__get__
#   File "pandas/_libs/index.pyx", line 193, in pandas._libs.index.IndexEngine._do_monotonic_check
#   File "pandas/_libs/index.pyx", line 210, in pandas._libs.index.IndexEngine._call_monotonic
#   File "pandas/_libs/algos.pyx", line 760, in pandas._libs.algos.is_monotonic
#   File "/shared-libs/python3.9/py/lib/python3.9/site-packages/pandas/core/generic.py", line 1442, in __nonzero__
#     raise ValueError(
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# 172.3.22.214 - - [03/May/2023 09:10:21] "POST /_dash-update-component HTTP/1.1" 500 -
# [2023-05-03 09:10:21,350] ERROR in app: Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/root/venv/lib/python3.9/site-packages/flask/app.py", line 2190, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/root/venv/lib/python3.9/site-packages/flask/app.py", line 1486, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/root/venv/lib/python3.9/site-packages/flask/app.py", line 1484, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/root/venv/lib/python3.9/site-packages/flask/app.py", line 1469, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#   File "/root/venv/lib/python3.9/site-packages/dash/dash.py", line 1283, in dispatch
#     ctx.run(
#   File "/root/venv/lib/python3.9/site-packages/dash/_callback.py", line 450, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "/tmp/ipykernel_127/1041133795.py", line 110, in update_histogram
#     df_robust[column] = (df_robust[column] - df_robust[column].median())  / (df_robust[column].quantile(0.75) - df_robust[column].quantile(0.25))
#   File "/shared-libs/python3.9/py/lib/python3.9/site-packages/pandas/core/frame.py", line 3024, in __getitem__
#     indexer = self.columns.get_loc(key)
#   File "/shared-libs/python3.9/py/lib/python3.9/site-packages/pandas/core/indexes/base.py", line 3081, in get_loc
#     return self._engine.get_loc(casted_key)
#   File "pandas/_libs/index.pyx", line 70, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas/_libs/index.pyx", line 96, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas/_libs/index.pyx", line 109, in pandas._libs.index.IndexEngine._get_loc_duplicates
#   File "pandas/_libs/index.pyx", line 176, in pandas._libs.index.IndexEngine.is_monotonic_increasing.__get__
#   File "pandas/_libs/index.pyx", line 193, in pandas._libs.index.IndexEngine._do_monotonic_check
#   File "pandas/_libs/index.pyx", line 210, in pandas._libs.index.IndexEngine._call_monotonic
#   File "pandas/_libs/algos.pyx", line 760, in pandas._libs.algos.is_monotonic
#   File "/shared-libs/python3.9/py/lib/python3.9/site-packages/pandas/core/generic.py", line 1442, in __nonzero__
#     raise ValueError(
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# 172.3.22.214 - - [03/May/2023 09:10:21] "POST /_dash-update-component HTTP/1.1" 500 -
# [2023-05-03 09:10:21,355] ERROR in app: Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/root/venv/lib/python3.9/site-packages/flask/app.py", line 2190, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/root/venv/lib/python3.9/site-packages/flask/app.py", line 1486, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/root/venv/lib/python3.9/site-packages/flask/app.py", line 1484, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/root/venv/lib/python3.9/site-packages/flask/app.py", line 1469, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#   File "/root/venv/lib/python3.9/site-packages/dash/dash.py", line 1283, in dispatch
#     ctx.run(
#   File "/root/venv/lib/python3.9/site-packages/dash/_callback.py", line 450, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "/tmp/ipykernel_127/1041133795.py", line 337, in update_prediction_months_output
#     values_col = df[index]
#   File "/shared-libs/python3.9/py/lib/python3.9/site-packages/pandas/core/frame.py", line 3024, in __getitem__
#     indexer = self.columns.get_loc(key)
#   File "/shared-libs/python3.9/py/lib/python3.9/site-packages/pandas/core/indexes/base.py", line 3081, in get_loc
#     return self._engine.get_loc(casted_key)
#   File "pandas/_libs/index.pyx", line 70, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas/_libs/index.pyx", line 96, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas/_libs/index.pyx", line 109, in pandas._libs.index.IndexEngine._get_loc_duplicates
#   File "pandas/_libs/index.pyx", line 176, in pandas._libs.index.IndexEngine.is_monotonic_increasing.__get__
#   File "pandas/_libs/index.pyx", line 193, in pandas._libs.index.IndexEngine._do_monotonic_check
#   File "pandas/_libs/index.pyx", line 210, in pandas._libs.index.IndexEngine._call_monotonic
#   File "pandas/_libs/algos.pyx", line 760, in pandas._libs.algos.is_monotonic
#   File "/shared-libs/python3.9/py/lib/python3.9/site-packages/pandas/core/generic.py", line 1442, in __nonzero__
#     raise ValueError(
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File pandas/_libs/hashtable_class_helper.pxi:4588, in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# File /shared-libs/python3.9/py/lib/python3.9/site-packages/pandas/core/generic.py:1785, in NDFrame.__hash__(self)
#    1784 def __hash__(self) -> int:
# -> 1785     raise TypeError(
#    1786         f"{repr(type(self).__name__)} objects are mutable, "
#    1787         f"thus they cannot be hashed"
#    1788     )
#
# TypeError: 'Series' objects are mutable, thus they cannot be hashed
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas/_libs/hashtable_class_helper.pxi", line 4588, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# 172.3.150.40 - - [03/May/2023 09:10:21] "POST /_dash-update-component HTTP/1.1" 500 -
#   File "/shared-libs/python3.9/py/lib/python3.9/site-packages/pandas/core/generic.py", line 1785, in __hash__
#     raise TypeError(
# TypeError: 'Series' objects are mutable, thus they cannot be hashed
# [2023-05-03 09:10:21,548] ERROR in app: Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/root/venv/lib/python3.9/site-packages/flask/app.py", line 2190, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/root/venv/lib/python3.9/site-packages/flask/app.py", line 1486, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/root/venv/lib/python3.9/site-packages/flask/app.py", line 1484, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/root/venv/lib/python3.9/site-packages/flask/app.py", line 1469, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#   File "/root/venv/lib/python3.9/site-packages/dash/dash.py", line 1283, in dispatch
#     ctx.run(
#   File "/root/venv/lib/python3.9/site-packages/dash/_callback.py", line 450, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "/tmp/ipykernel_127/1041133795.py", line 139, in update_violin_plot
#     df_robust[column] = (df_robust[column] - df_robust[column].median())  / (df_robust[column].quantile(0.75) - df_robust[column].quantile(0.25))
#   File "/shared-libs/python3.9/py/lib/python3.9/site-packages/pandas/core/frame.py", line 3024, in __getitem__
#     indexer = self.columns.get_loc(key)
#   File "/shared-libs/python3.9/py/lib/python3.9/site-packages/pandas/core/indexes/base.py", line 3081, in get_loc
#     return self._engine.get_loc(casted_key)
#   File "pandas/_libs/index.pyx", line 70, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas/_libs/index.pyx", line 96, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas/_libs/index.pyx", line 109, in pandas._libs.index.IndexEngine._get_loc_duplicates
#   File "pandas/_libs/index.pyx", line 176, in pandas._libs.index.IndexEngine.is_monotonic_increasing.__get__
#   File "pandas/_libs/index.pyx", line 193, in pandas._libs.index.IndexEngine._do_monotonic_check
#   File "pandas/_libs/index.pyx", line 210, in pandas._libs.index.IndexEngine._call_monotonic
#   File "pandas/_libs/algos.pyx", line 760, in pandas._libs.algos.is_monotonic
#   File "/shared-libs/python3.9/py/lib/python3.9/site-packages/pandas/core/generic.py", line 1442, in __nonzero__
#     raise ValueError(
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# 172.3.22.214 - - [03/May/2023 09:10:21] "POST /_dash-update-component HTTP/1.1" 500 -
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File pandas/_libs/hashtable_class_helper.pxi:4588, in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# File /shared-libs/python3.9/py/lib/python3.9/site-packages/pandas/core/generic.py:1785, in NDFrame.__hash__(self)
#    1784 def __hash__(self) -> int:
# -> 1785     raise TypeError(
#    1786         f"{repr(type(self).__name__)} objects are mutable, "
#    1787         f"thus they cannot be hashed"
#    1788     )
#
# TypeError: 'Series' objects are mutable, thus they cannot be hashed
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas/_libs/hashtable_class_helper.pxi", line 4588, in pandas._libs.hashtable.PyObjectHashTable.map_locations
#   File "/shared-libs/python3.9/py/lib/python3.9/site-packages/pandas/core/generic.py", line 1785, in __hash__
#     raise TypeError(
# TypeError: 'Series' objects are mutable, thus they cannot be hashed
# [2023-05-03 09:10:21,748] ERROR in app: Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/root/venv/lib/python3.9/site-packages/flask/app.py", line 2190, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/root/venv/lib/python3.9/site-packages/flask/app.py", line 1486, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/root/venv/lib/python3.9/site-packages/flask/app.py", line 1484, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/root/venv/lib/python3.9/site-packages/flask/app.py", line 1469, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#   File "/root/venv/lib/python3.9/site-packages/dash/dash.py", line 1283, in dispatch
#     ctx.run(
#   File "/root/venv/lib/python3.9/site-packages/dash/_callback.py", line 450, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "/tmp/ipykernel_127/1041133795.py", line 211, in update_time_series_decomposition_plot
#     df_robust[column] = (df_robust[column] - df_robust[column].median())  / (df_robust[column].quantile(0.75) - df_robust[column].quantile(0.25))
#   File "/shared-libs/python3.9/py/lib/python3.9/site-packages/pandas/core/frame.py", line 3024, in __getitem__
#     indexer = self.columns.get_loc(key)
#   File "/shared-libs/python3.9/py/lib/python3.9/site-packages/pandas/core/indexes/base.py", line 3081, in get_loc
#     return self._engine.get_loc(casted_key)
#   File "pandas/_libs/index.pyx", line 70, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas/_libs/index.pyx", line 96, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas/_libs/index.pyx", line 109, in pandas._libs.index.IndexEngine._get_loc_duplicates
#   File "pandas/_libs/index.pyx", line 176, in pandas._libs.index.IndexEngine.is_monotonic_increasing.__get__
#   File "pandas/_libs/index.pyx", line 193, in pandas._libs.index.IndexEngine._do_monotonic_check
#   File "pandas/_libs/index.pyx", line 210, in pandas._libs.index.IndexEngine._call_monotonic
#   File "pandas/_libs/algos.pyx", line 760, in pandas._libs.algos.is_monotonic
#   File "/shared-libs/python3.9/py/lib/python3.9/site-packages/pandas/core/generic.py", line 1442, in __nonzero__
#     raise ValueError(
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# 172.3.150.40 - - [03/May/2023 09:10:21] "POST /_dash-update-component HTTP/1.1" 500 -
# /shared-libs/python3.9/py/lib/python3.9/site-packages/plotly/tools.py:460: DeprecationWarning:
#
# plotly.tools.make_subplots is deprecated, please use plotly.subplots.make_subplots instead
#
# /shared-libs/python3.9/py/lib/python3.9/site-packages/plotly/tools.py:460: DeprecationWarning:
#
# plotly.tools.make_subplots is deprecated, please use plotly.subplots.make_subplots instead
#
# 2023-05-03 09:10:23.791038: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2023-05-03 09:10:23.791092: W tensorflow/stream_executor/cuda/cuda_driver.cc:263] failed call to cuInit: UNKNOWN ERROR (303)
# 2023-05-03 09:10:23.791115: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (p-638889fe-2546-41ac-8d2f-f9d8b29d307c): /proc/driver/nvidia/version does not exist
# 2023-05-03 09:10:23.791411: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 172.3.22.214 - - [03/May/2023 09:10:23] "POST /_dash-update-component HTTP/1.1" 200 -
# 172.3.22.214 - - [03/May/2023 09:10:23] "POST /_dash-update-component HTTP/1.1" 200 -
# 172.3.22.214 - - [03/May/2023 09:10:24] "POST /_dash-update-component HTTP/1.1" 200 -
# 172.3.22.214 - - [03/May/2023 09:10:24] "POST /_dash-update-component HTTP/1.1" 200 -
# 172.3.22.214 - - [03/May/2023 09:10:24] "POST /_dash-update-component HTTP/1.1" 200 -
# Epoch 1/100
# 172.3.22.214 - - [03/May/2023 09:10:26] "POST /_dash-update-component HTTP/1.1" 200 -
# 4/4 [==============================] - 2s 127ms/step - loss: 0.2335 - val_loss: 1.3298
# Epoch 2/100
# 4/4 [==============================] - 0s 17ms/step - loss: 0.2015 - val_loss: 1.1758
# Epoch 3/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.1712 - val_loss: 1.0042
# Epoch 4/100
# 4/4 [==============================] - 0s 25ms/step - loss: 0.1434 - val_loss: 0.8545
# Epoch 5/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.1166 - val_loss: 0.7045
# Epoch 6/100
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0916 - val_loss: 0.5598
# Epoch 7/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0699 - val_loss: 0.4199
# Epoch 8/100
# 4/4 [==============================] - 0s 26ms/step - loss: 0.0495 - val_loss: 0.3061
# Epoch 9/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0316 - val_loss: 0.2109
# Epoch 10/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0180 - val_loss: 0.1308
# Epoch 11/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0083 - val_loss: 0.0740
# Epoch 12/100
# 4/4 [==============================] - 0s 24ms/step - loss: 0.0029 - val_loss: 0.0347
# Epoch 13/100
# 4/4 [==============================] - 0s 7ms/step - loss: 8.2609e-04 - val_loss: 0.0126
# Epoch 14/100
# 4/4 [==============================] - 0s 20ms/step - loss: 9.7789e-04 - val_loss: 0.0039
# Epoch 15/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0018 - val_loss: 0.0017
# Epoch 16/100
# 4/4 [==============================] - 0s 24ms/step - loss: 0.0021 - val_loss: 0.0021
# Epoch 17/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0018 - val_loss: 0.0040
# Epoch 18/100
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0012 - val_loss: 0.0075
# Epoch 19/100
# 4/4 [==============================] - 0s 7ms/step - loss: 7.8667e-04 - val_loss: 0.0110
# Epoch 20/100
# 4/4 [==============================] - 0s 23ms/step - loss: 6.1007e-04 - val_loss: 0.0147
# Epoch 21/100
# 4/4 [==============================] - 0s 17ms/step - loss: 6.0164e-04 - val_loss: 0.0172
# Epoch 22/100
# 4/4 [==============================] - 0s 10ms/step - loss: 6.5391e-04 - val_loss: 0.0180
# Epoch 23/100
# 4/4 [==============================] - 0s 7ms/step - loss: 6.7622e-04 - val_loss: 0.0173
# Epoch 24/100
# 4/4 [==============================] - 0s 7ms/step - loss: 6.6086e-04 - val_loss: 0.0158
# Epoch 25/100
# 4/4 [==============================] - 0s 8ms/step - loss: 6.2528e-04 - val_loss: 0.0140
# Epoch 26/100
# 4/4 [==============================] - 0s 7ms/step - loss: 5.9714e-04 - val_loss: 0.0121
# Epoch 27/100
# 4/4 [==============================] - 0s 7ms/step - loss: 5.8848e-04 - val_loss: 0.0107
# Epoch 28/100
# 4/4 [==============================] - 0s 7ms/step - loss: 5.8920e-04 - val_loss: 0.0102
# Epoch 29/100
# 4/4 [==============================] - 0s 24ms/step - loss: 5.8811e-04 - val_loss: 0.0102
# Epoch 30/100
# 4/4 [==============================] - 0s 23ms/step - loss: 5.9068e-04 - val_loss: 0.0108
# Epoch 31/100
# 4/4 [==============================] - 0s 8ms/step - loss: 5.9121e-04 - val_loss: 0.0109
# Epoch 32/100
# 4/4 [==============================] - 0s 7ms/step - loss: 5.8626e-04 - val_loss: 0.0107
# Epoch 33/100
# 4/4 [==============================] - 0s 23ms/step - loss: 5.8519e-04 - val_loss: 0.0108
# Epoch 34/100
# 4/4 [==============================] - 0s 7ms/step - loss: 5.8685e-04 - val_loss: 0.0112
# Epoch 35/100
# 4/4 [==============================] - 0s 21ms/step - loss: 5.8642e-04 - val_loss: 0.0116
# Epoch 36/100
# 4/4 [==============================] - 0s 7ms/step - loss: 5.8593e-04 - val_loss: 0.0113
# Epoch 37/100
# 4/4 [==============================] - 0s 21ms/step - loss: 5.8510e-04 - val_loss: 0.0109
# Epoch 38/100
# 4/4 [==============================] - 0s 8ms/step - loss: 5.8399e-04 - val_loss: 0.0108
# Epoch 39/100
# 4/4 [==============================] - 0s 20ms/step - loss: 5.8522e-04 - val_loss: 0.0108
# Epoch 40/100
# 4/4 [==============================] - 0s 7ms/step - loss: 5.8729e-04 - val_loss: 0.0102
# Epoch 41/100
# 4/4 [==============================] - 0s 7ms/step - loss: 5.8411e-04 - val_loss: 0.0104
# Epoch 42/100
# 4/4 [==============================] - 0s 16ms/step - loss: 5.8504e-04 - val_loss: 0.0105
# Epoch 43/100
# 4/4 [==============================] - 0s 7ms/step - loss: 5.8647e-04 - val_loss: 0.0102
# Epoch 44/100
# 4/4 [==============================] - 0s 14ms/step - loss: 5.8489e-04 - val_loss: 0.0105
# Epoch 45/100
# 4/4 [==============================] - 0s 7ms/step - loss: 5.8274e-04 - val_loss: 0.0111
# Epoch 46/100
# 4/4 [==============================] - 0s 21ms/step - loss: 5.8898e-04 - val_loss: 0.0111
# Epoch 47/100
# 4/4 [==============================] - 0s 7ms/step - loss: 5.8599e-04 - val_loss: 0.0102
# Epoch 48/100
# 4/4 [==============================] - 0s 19ms/step - loss: 5.8898e-04 - val_loss: 0.0102
# Epoch 49/100
# 4/4 [==============================] - 0s 7ms/step - loss: 5.8257e-04 - val_loss: 0.0110
# Epoch 50/100
# 4/4 [==============================] - 0s 7ms/step - loss: 5.8855e-04 - val_loss: 0.0113
# Epoch 51/100
# 4/4 [==============================] - 0s 9ms/step - loss: 5.8731e-04 - val_loss: 0.0108
# Epoch 52/100
# 4/4 [==============================] - 0s 8ms/step - loss: 5.8419e-04 - val_loss: 0.0100
# Epoch 53/100
# 4/4 [==============================] - 0s 22ms/step - loss: 5.8937e-04 - val_loss: 0.0102
# Epoch 54/100
# 4/4 [==============================] - 0s 7ms/step - loss: 5.8258e-04 - val_loss: 0.0111
# Epoch 55/100
# 4/4 [==============================] - 0s 19ms/step - loss: 5.8684e-04 - val_loss: 0.0114
# Epoch 56/100
# 4/4 [==============================] - 0s 7ms/step - loss: 5.8426e-04 - val_loss: 0.0109
# Epoch 57/100
# 4/4 [==============================] - 0s 20ms/step - loss: 5.8909e-04 - val_loss: 0.0102
# Epoch 58/100
# 4/4 [==============================] - 0s 7ms/step - loss: 5.9237e-04 - val_loss: 0.0107
# Epoch 59/100
# 4/4 [==============================] - 0s 8ms/step - loss: 5.8276e-04 - val_loss: 0.0109
# Epoch 60/100
# 4/4 [==============================] - 0s 11ms/step - loss: 5.8326e-04 - val_loss: 0.0109
# Epoch 61/100
# 4/4 [==============================] - 0s 7ms/step - loss: 5.8279e-04 - val_loss: 0.0107
# Epoch 62/100
# 4/4 [==============================] - 0s 7ms/step - loss: 5.8269e-04 - val_loss: 0.0106
# Epoch 63/100
# 4/4 [==============================] - 0s 7ms/step - loss: 5.8306e-04 - val_loss: 0.0110
# Epoch 64/100
# 4/4 [==============================] - 0s 30ms/step - loss: 5.8386e-04 - val_loss: 0.0105
# Epoch 65/100
# 4/4 [==============================] - 0s 7ms/step - loss: 5.8280e-04 - val_loss: 0.0101
# Epoch 66/100
# 4/4 [==============================] - 0s 14ms/step - loss: 5.8291e-04 - val_loss: 0.0102
# Epoch 67/100
# 4/4 [==============================] - 0s 7ms/step - loss: 5.8317e-04 - val_loss: 0.0106
# Epoch 68/100
# 4/4 [==============================] - 0s 23ms/step - loss: 5.8469e-04 - val_loss: 0.0108
# Epoch 69/100
# 4/4 [==============================] - 0s 9ms/step - loss: 5.8065e-04 - val_loss: 0.0102
# Epoch 70/100
# 4/4 [==============================] - 0s 16ms/step - loss: 5.8569e-04 - val_loss: 0.0103
# Epoch 71/100
# 4/4 [==============================] - 0s 7ms/step - loss: 5.8214e-04 - val_loss: 0.0105
# Epoch 72/100
# 4/4 [==============================] - 0s 22ms/step - loss: 5.8321e-04 - val_loss: 0.0104
# Epoch 73/100
# 4/4 [==============================] - 0s 8ms/step - loss: 5.8629e-04 - val_loss: 0.0105
# Epoch 74/100
# 4/4 [==============================] - 0s 14ms/step - loss: 5.9429e-04 - val_loss: 0.0113
# Epoch 75/100
# 4/4 [==============================] - 0s 8ms/step - loss: 5.8729e-04 - val_loss: 0.0103
# Epoch 76/100
# 4/4 [==============================] - 0s 7ms/step - loss: 5.8329e-04 - val_loss: 0.0104
# Epoch 77/100
# 4/4 [==============================] - 0s 22ms/step - loss: 5.8119e-04 - val_loss: 0.0105
# Epoch 78/100
# 4/4 [==============================] - 0s 7ms/step - loss: 5.8241e-04 - val_loss: 0.0105
# Epoch 79/100
# 4/4 [==============================] - 0s 23ms/step - loss: 5.8503e-04 - val_loss: 0.0100
# Epoch 80/100
# 4/4 [==============================] - 0s 7ms/step - loss: 5.8436e-04 - val_loss: 0.0104
# Epoch 81/100
# 4/4 [==============================] - 0s 23ms/step - loss: 5.8120e-04 - val_loss: 0.0102
# Epoch 82/100
# 4/4 [==============================] - 0s 7ms/step - loss: 5.8281e-04 - val_loss: 0.0106
# Epoch 83/100
# 4/4 [==============================] - 0s 18ms/step - loss: 5.8221e-04 - val_loss: 0.0102
# Epoch 84/100
# 4/4 [==============================] - 0s 7ms/step - loss: 5.8505e-04 - val_loss: 0.0101
# Epoch 85/100
# 4/4 [==============================] - 0s 7ms/step - loss: 5.8275e-04 - val_loss: 0.0094
# Epoch 86/100
# 4/4 [==============================] - 0s 22ms/step - loss: 5.8233e-04 - val_loss: 0.0097
# Epoch 87/100
# 4/4 [==============================] - 0s 8ms/step - loss: 5.8191e-04 - val_loss: 0.0102
# Epoch 88/100
# 4/4 [==============================] - 0s 8ms/step - loss: 5.8129e-04 - val_loss: 0.0107
# Epoch 89/100
# 4/4 [==============================] - 0s 7ms/step - loss: 5.8107e-04 - val_loss: 0.0105
# Epoch 90/100
# 4/4 [==============================] - 0s 23ms/step - loss: 5.8241e-04 - val_loss: 0.0104
# Epoch 91/100
# 4/4 [==============================] - 0s 8ms/step - loss: 5.8411e-04 - val_loss: 0.0106
# Epoch 92/100
# 4/4 [==============================] - 0s 21ms/step - loss: 5.8270e-04 - val_loss: 0.0101
# Epoch 93/100
# 4/4 [==============================] - 0s 7ms/step - loss: 5.8060e-04 - val_loss: 0.0094
# Epoch 94/100
# 4/4 [==============================] - 0s 21ms/step - loss: 5.8911e-04 - val_loss: 0.0099
# Epoch 95/100
# 4/4 [==============================] - 0s 8ms/step - loss: 5.8217e-04 - val_loss: 0.0101
# Epoch 96/100
# 4/4 [==============================] - 0s 21ms/step - loss: 5.8020e-04 - val_loss: 0.0102
# Epoch 97/100
# 4/4 [==============================] - 0s 10ms/step - loss: 5.8179e-04 - val_loss: 0.0102
# Epoch 98/100
# 4/4 [==============================] - 0s 20ms/step - loss: 5.8396e-04 - val_loss: 0.0106
# Epoch 99/100
# 4/4 [==============================] - 0s 7ms/step - loss: 5.8182e-04 - val_loss: 0.0100
# Epoch 100/100
# 4/4 [==============================] - 0s 7ms/step - loss: 5.7969e-04 - val_loss: 0.0099
# 1/1 [==============================] - 0s 290ms/step
# [2023-05-03 09:10:31,753] ERROR in app: Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/root/venv/lib/python3.9/site-packages/flask/app.py", line 2190, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/root/venv/lib/python3.9/site-packages/flask/app.py", line 1486, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/root/venv/lib/python3.9/site-packages/flask/app.py", line 1484, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/root/venv/lib/python3.9/site-packages/flask/app.py", line 1469, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#   File "/root/venv/lib/python3.9/site-packages/dash/dash.py", line 1283, in dispatch
#     ctx.run(
#   File "/root/venv/lib/python3.9/site-packages/dash/_callback.py", line 450, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "/tmp/ipykernel_127/1041133795.py", line 406, in update_prediction_months_output
#     future_dates = pd.date_range(start_date,end_date, freq='MS')
#   File "/shared-libs/python3.9/py/lib/python3.9/site-packages/pandas/core/indexes/datetimes.py", line 1069, in date_range
#     dtarr = DatetimeArray._generate_range(
#   File "/shared-libs/python3.9/py/lib/python3.9/site-packages/pandas/core/arrays/datetimes.py", line 373, in _generate_range
#     raise ValueError(
# ValueError: Of the four parameters: start, end, periods, and freq, exactly three must be specified
# 172.3.18.60 - - [03/May/2023 09:10:31] "POST /_dash-update-component HTTP/1.1" 500 -
# [2023-05-03 09:10:33,925] ERROR in app: Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/root/venv/lib/python3.9/site-packages/flask/app.py", line 2190, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/root/venv/lib/python3.9/site-packages/flask/app.py", line 1486, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/root/venv/lib/python3.9/site-packages/flask/app.py", line 1484, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/root/venv/lib/python3.9/site-packages/flask/app.py", line 1469, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#   File "/root/venv/lib/python3.9/site-packages/dash/dash.py", line 1283, in dispatch
#     ctx.run(
#   File "/root/venv/lib/python3.9/site-packages/dash/_callback.py", line 450, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "/tmp/ipykernel_127/1041133795.py", line 317, in update_prediction_months_output
#     end_month = pd.to_datetime(end_date).strftime('%B')
# AttributeError: 'NoneType' object has no attribute 'strftime'
# 172.3.150.40 - - [03/May/2023 09:10:33] "POST /_dash-update-component HTTP/1.1" 500 -
# Epoch 1/100
# 4/4 [==============================] - 2s 114ms/step - loss: 0.2799 - val_loss: 1.5336
# Epoch 2/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.2492 - val_loss: 1.3674
# Epoch 3/100
# 4/4 [==============================] - 0s 24ms/step - loss: 0.2187 - val_loss: 1.2048
# Epoch 4/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.1894 - val_loss: 1.0465
# Epoch 5/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.1625 - val_loss: 0.8876
# Epoch 6/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1352 - val_loss: 0.7192
# Epoch 7/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.1090 - val_loss: 0.5627
# Epoch 8/100
# 4/4 [==============================] - 0s 24ms/step - loss: 0.0842 - val_loss: 0.4098
# Epoch 9/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0604 - val_loss: 0.2733
# Epoch 10/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0494172.3.150.40 - - [03/May/2023 09:10:36] "POST /_dash-update-component HTTP/1.1" 200 -
# 4/4 [==============================] - 0s 24ms/step - loss: 0.0398 - val_loss: 0.1568
# Epoch 11/100
# 4/4 [==============================] - 0s 28ms/step - loss: 0.0234 - val_loss: 0.0737
# Epoch 12/100
# 4/4 [==============================] - 0s 27ms/step - loss: 0.0108 - val_loss: 0.0264
# Epoch 13/100
# 4/4 [==============================] - 0s 31ms/step - loss: 0.0035 - val_loss: 0.0046
# Epoch 14/100
# 4/4 [==============================] - 0s 39ms/step - loss: 0.0011 - val_loss: 1.3550e-04
# Epoch 15/100
# 4/4 [==============================] - 0s 25ms/step - loss: 0.0016 - val_loss: 0.0025
# Epoch 16/100
# 4/4 [==============================] - 0s 27ms/step - loss: 0.0025 - val_loss: 0.0035
# Epoch 17/100
# 4/4 [==============================] - 0s 30ms/step - loss: 0.0026 - val_loss: 0.0016
# Epoch 18/100
# 4/4 [==============================] - 0s 33ms/step - loss: 0.0020 - val_loss: 1.0028e-04
# Epoch 19/100
# 4/4 [==============================] - 0s 27ms/step - loss: 0.0012 - val_loss: 0.0018
# Epoch 20/100
# 4/4 [==============================] - 0s 9ms/step - loss: 7.7452e-04 - val_loss: 0.0060
# Epoch 21/100
# 4/4 [==============================] - 0s 10ms/step - loss: 6.3596e-04 - val_loss: 0.0106
# Epoch 22/100
# 2/4 [==============>...............] - ETA: 0s - loss: 6.4960e-04Epoch 1/100
# 4/4 [==============================] - 0s 27ms/step - loss: 6.7140e-04 - val_loss: 0.0136
# Epoch 23/100
# 4/4 [==============================] - 0s 32ms/step - loss: 7.1794e-04 - val_loss: 0.0151
# Epoch 24/100
# 4/4 [==============================] - 0s 27ms/step - loss: 7.1556e-04 - val_loss: 0.0153
# Epoch 25/100
# 4/4 [==============================] - 0s 27ms/step - loss: 6.7221e-04 - val_loss: 0.0141
# Epoch 26/100
# 4/4 [==============================] - 0s 33ms/step - loss: 6.2932e-04 - val_loss: 0.0127
# Epoch 27/100
# 4/4 [==============================] - 0s 36ms/step - loss: 6.0745e-04 - val_loss: 0.0113
# Epoch 28/100
# 4/4 [==============================] - 0s 24ms/step - loss: 6.0122e-04 - val_loss: 0.0108
# Epoch 29/100
# 4/4 [==============================] - 0s 9ms/step - loss: 6.0676e-04 - val_loss: 0.0104
# Epoch 30/100
# 4/4 [==============================] - 0s 10ms/step - loss: 6.0903e-04 - val_loss: 0.0109
# Epoch 31/100
# 4/4 [==============================] - 0s 28ms/step - loss: 6.0645e-04 - val_loss: 0.0114
# Epoch 32/100
# 4/4 [==============================] - 0s 30ms/step - loss: 6.0282e-04 - val_loss: 0.0116
# Epoch 33/100
# 4/4 [==============================] - 0s 26ms/step - loss: 6.0120e-04 - val_loss: 0.0120
# Epoch 34/100
# 4/4 [==============================] - 0s 9ms/step - loss: 6.0287e-04 - val_loss: 0.0123
# Epoch 35/100
# 4/4 [==============================] - 0s 10ms/step - loss: 6.0079e-04 - val_loss: 0.0120
# Epoch 36/100
# 4/4 [==============================] - 0s 31ms/step - loss: 6.0257e-04 - val_loss: 0.0118
# Epoch 37/100
# 4/4 [==============================] - 0s 39ms/step - loss: 6.0214e-04 - val_loss: 0.0117
# Epoch 38/100
# 4/4 [==============================] - 0s 10ms/step - loss: 5.9975e-04 - val_loss: 0.0116
# Epoch 39/100
# 4/4 [==============================] - 0s 28ms/step - loss: 6.0357e-04 - val_loss: 0.0116
# Epoch 40/100
# 4/4 [==============================] - 0s 28ms/step - loss: 6.0249e-04 - val_loss: 0.0113
# Epoch 41/100
# 4/4 [==============================] - 0s 31ms/step - loss: 6.0069e-04 - val_loss: 0.0112
# Epoch 42/100
# 4/4 [==============================] - 0s 27ms/step - loss: 6.0396e-04 - val_loss: 0.0110
# Epoch 43/100
# 4/4 [==============================] - 0s 29ms/step - loss: 6.0026e-04 - val_loss: 0.0114
# Epoch 44/100
# 4/4 [==============================] - 0s 12ms/step - loss: 5.9902e-04 - val_loss: 0.0117
# Epoch 45/100
# 4/4 [==============================] - 0s 9ms/step - loss: 6.0171e-04 - val_loss: 0.0115
# Epoch 46/100
# 4/4 [==============================] - 0s 30ms/step - loss: 6.0124e-04 - val_loss: 0.0112
# Epoch 47/100
# 4/4 [==============================] - 0s 29ms/step - loss: 5.9931e-04 - val_loss: 0.0113
# Epoch 48/100
# 4/4 [==============================] - 0s 42ms/step - loss: 5.9985e-04 - val_loss: 0.0114
# Epoch 49/100
# 4/4 [==============================] - 0s 12ms/step - loss: 6.0027e-04 - val_loss: 0.0112
# Epoch 50/100
# 4/4 [==============================] - 0s 29ms/step - loss: 6.0559e-04 - val_loss: 0.0111
# Epoch 51/100
# 4/4 [==============================] - 0s 30ms/step - loss: 6.0124e-04 - val_loss: 0.0119
# Epoch 52/100
# 4/4 [==============================] - 0s 31ms/step - loss: 6.0654e-04 - val_loss: 0.0115
# Epoch 53/100
# 4/4 [==============================] - 0s 29ms/step - loss: 6.0119e-04 - val_loss: 0.0118
# Epoch 54/100
# 4/4 [==============================] - 0s 26ms/step - loss: 5.9783e-04 - val_loss: 0.0112
# Epoch 55/100
# 4/4 [==============================] - 0s 28ms/step - loss: 6.0010e-04 - val_loss: 0.0109
# Epoch 56/100
# 4/4 [==============================] - 0s 7ms/step - loss: 6.0199e-04 - val_loss: 0.0113
# Epoch 57/100
# 4/4 [==============================] - 0s 32ms/step - loss: 6.0026e-04 - val_loss: 0.0111
# Epoch 58/100
# 4/4 [==============================] - 0s 30ms/step - loss: 5.9889e-04 - val_loss: 0.0113
# Epoch 59/100
# 4/4 [==============================] - 0s 32ms/step - loss: 5.9858e-04 - val_loss: 0.0115
# Epoch 60/100
# 4/4 [==============================] - 0s 30ms/step - loss: 5.9812e-04 - val_loss: 0.0119
# Epoch 61/100
# 4/4 [==============================] - 0s 28ms/step - loss: 5.9854e-04 - val_loss: 0.0120
# Epoch 62/100
# 4/4 [==============================] - 0s 30ms/step - loss: 5.9906e-04 - val_loss: 0.0118
# Epoch 63/100
# 4/4 [==============================] - 0s 10ms/step - loss: 5.9896e-04 - val_loss: 0.0118
# Epoch 64/100
# 4/4 [==============================] - 0s 35ms/step - loss: 6.0365e-04 - val_loss: 0.0118
# Epoch 65/100
# 4/4 [==============================] - 0s 9ms/step - loss: 6.0355e-04 - val_loss: 0.0111
# Epoch 66/100
# 4/4 [==============================] - 0s 30ms/step - loss: 6.0030e-04 - val_loss: 0.0117
# Epoch 67/100
# 4/4 [==============================] - 0s 29ms/step - loss: 6.0035e-04 - val_loss: 0.0119
# Epoch 68/100
# 4/4 [==============================] - 0s 26ms/step - loss: 5.9997e-04 - val_loss: 0.0113
# Epoch 69/100
# 4/4 [==============================] - 0s 10ms/step - loss: 5.9912e-04 - val_loss: 0.0119
# Epoch 70/100
# 4/4 [==============================] - 0s 10ms/step - loss: 5.9987e-04 - val_loss: 0.0122
# Epoch 71/100
# 4/4 [==============================] - 0s 35ms/step - loss: 5.9819e-04 - val_loss: 0.0117
# Epoch 72/100
# 4/4 [==============================] - 0s 25ms/step - loss: 5.9831e-04 - val_loss: 0.0110
# Epoch 73/100
# 4/4 [==============================] - 0s 28ms/step - loss: 5.9874e-04 - val_loss: 0.0109
# Epoch 74/100
# 4/4 [==============================] - 0s 28ms/step - loss: 5.9975e-04 - val_loss: 0.0110
# Epoch 75/100
# 4/4 [==============================] - 5s 309ms/step - loss: 0.2396 - val_loss: 1.3856
# 4/4 [==============================] - 0s 7ms/step - loss: 5.9722e-04 - val_loss: 0.0106
# Epoch 76/100
# Epoch 2/100
# ...
#     rv = self.dispatch_request()
#   File "/root/venv/lib/python3.9/site-packages/flask/app.py", line 1469, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#   File "/root/venv/lib/python3.9/site-packages/dash/dash.py", line 1283, in dispatch
#     ctx.run(
#   File "/root/venv/lib/python3.9/site-packages/dash/_callback.py", line 450, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "/tmp/ipykernel_127/1041133795.py", line 110, in update_histogram
#     df_robust[column] = (df_robust[column] - df_robust[column].median())  / (df_robust[column].quantile(0.75) - df_robust[column].quantile(0.25))
#   File "/shared-libs/python3.9/py/lib/python3.9/site-packages/pandas/core/frame.py", line 3024, in __getitem__
#     indexer = self.columns.get_loc(key)
#   File "/shared-libs/python3.9/py/lib/python3.9/site-packages/pandas/core/indexes/base.py", line 3081, in get_loc
#     return self._engine.get_loc(casted_key)
#   File "pandas/_libs/index.pyx", line 70, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas/_libs/index.pyx", line 96, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas/_libs/index.pyx", line 109, in pandas._libs.index.IndexEngine._get_loc_duplicates
#   File "pandas/_libs/index.pyx", line 176, in pandas._libs.index.IndexEngine.is_monotonic_increasing.__get__
#   File "pandas/_libs/index.pyx", line 193, in pandas._libs.index.IndexEngine._do_monotonic_check
#   File "pandas/_libs/index.pyx", line 210, in pandas._libs.index.IndexEngine._call_monotonic
#   File "pandas/_libs/algos.pyx", line 760, in pandas._libs.algos.is_monotonic
#   File "/shared-libs/python3.9/py/lib/python3.9/site-packages/pandas/core/generic.py", line 1442, in __nonzero__
#     raise ValueError(
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# 172.3.18.60 - - [03/May/2023 09:14:08] "POST /_dash-update-component HTTP/1.1" 500 -
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File pandas/_libs/hashtable_class_helper.pxi:4588, in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# File /shared-libs/python3.9/py/lib/python3.9/site-packages/pandas/core/generic.py:1785, in NDFrame.__hash__(self)
#    1784 def __hash__(self) -> int:
# -> 1785     raise TypeError(
#    1786         f"{repr(type(self).__name__)} objects are mutable, "
#    1787         f"thus they cannot be hashed"
#    1788     )
#
# TypeError: 'Series' objects are mutable, thus they cannot be hashed
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas/_libs/hashtable_class_helper.pxi", line 4588, in pandas._libs.hashtable.PyObjectHashTable.map_locations
#   File "/shared-libs/python3.9/py/lib/python3.9/site-packages/pandas/core/generic.py", line 1785, in __hash__
#     raise TypeError(
# TypeError: 'Series' objects are mutable, thus they cannot be hashed
# [2023-05-03 09:14:08,780] ERROR in app: Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/root/venv/lib/python3.9/site-packages/flask/app.py", line 2190, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/root/venv/lib/python3.9/site-packages/flask/app.py", line 1486, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/root/venv/lib/python3.9/site-packages/flask/app.py", line 1484, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/root/venv/lib/python3.9/site-packages/flask/app.py", line 1469, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#   File "/root/venv/lib/python3.9/site-packages/dash/dash.py", line 1283, in dispatch
#     ctx.run(
#   File "/root/venv/lib/python3.9/site-packages/dash/_callback.py", line 450, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "/tmp/ipykernel_127/1041133795.py", line 337, in update_prediction_months_output
#     values_col = df[index]
#   File "/shared-libs/python3.9/py/lib/python3.9/site-packages/pandas/core/frame.py", line 3024, in __getitem__
#     indexer = self.columns.get_loc(key)
#   File "/shared-libs/python3.9/py/lib/python3.9/site-packages/pandas/core/indexes/base.py", line 3081, in get_loc
#     return self._engine.get_loc(casted_key)
#   File "pandas/_libs/index.pyx", line 70, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas/_libs/index.pyx", line 96, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas/_libs/index.pyx", line 109, in pandas._libs.index.IndexEngine._get_loc_duplicates
#   File "pandas/_libs/index.pyx", line 176, in pandas._libs.index.IndexEngine.is_monotonic_increasing.__get__
#   File "pandas/_libs/index.pyx", line 193, in pandas._libs.index.IndexEngine._do_monotonic_check
#   File "pandas/_libs/index.pyx", line 210, in pandas._libs.index.IndexEngine._call_monotonic
#   File "pandas/_libs/algos.pyx", line 760, in pandas._libs.algos.is_monotonic
#   File "/shared-libs/python3.9/py/lib/python3.9/site-packages/pandas/core/generic.py", line 1442, in __nonzero__
#     raise ValueError(
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# 172.3.150.40 - - [03/May/2023 09:14:08] "POST /_dash-update-component HTTP/1.1" 500 -
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File pandas/_libs/hashtable_class_helper.pxi:4588, in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# File /shared-libs/python3.9/py/lib/python3.9/site-packages/pandas/core/generic.py:1785, in NDFrame.__hash__(self)
#    1784 def __hash__(self) -> int:
# -> 1785     raise TypeError(
#    1786         f"{repr(type(self).__name__)} objects are mutable, "
#    1787         f"thus they cannot be hashed"
#    1788     )
#
# TypeError: 'Series' objects are mutable, thus they cannot be hashed
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas/_libs/hashtable_class_helper.pxi", line 4588, in pandas._libs.hashtable.PyObjectHashTable.map_locations
#   File "/shared-libs/python3.9/py/lib/python3.9/site-packages/pandas/core/generic.py", line 1785, in __hash__
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File pandas/_libs/hashtable_class_helper.pxi:4588, in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# File /shared-libs/python3.9/py/lib/python3.9/site-packages/pandas/core/generic.py:1785, in NDFrame.__hash__(self)
#    1784 def __hash__(self) -> int:
# -> 1785     raise TypeError(
#    1786         f"{repr(type(self).__name__)} objects are mutable, "
#    1787         f"thus they cannot be hashed"
#    1788     )
#
# TypeError: 'Series' objects are mutable, thus they cannot be hashed
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas/_libs/hashtable_class_helper.pxi", line 4588, in pandas._libs.hashtable.PyObjectHashTable.map_locations
#     raise TypeError(
# TypeError: 'Series' objects are mutable, thus they cannot be hashed
#   File "/shared-libs/python3.9/py/lib/python3.9/site-packages/pandas/core/generic.py", line 1785, in __hash__
# [2023-05-03 09:14:08,878] ERROR in app: Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/root/venv/lib/python3.9/site-packages/flask/app.py", line 2190, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/root/venv/lib/python3.9/site-packages/flask/app.py", line 1486, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/root/venv/lib/python3.9/site-packages/flask/app.py", line 1484, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/root/venv/lib/python3.9/site-packages/flask/app.py", line 1469, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#   File "/root/venv/lib/python3.9/site-packages/dash/dash.py", line 1283, in dispatch
#     ctx.run(
#   File "/root/venv/lib/python3.9/site-packages/dash/_callback.py", line 450, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "/tmp/ipykernel_127/1041133795.py", line 80, in update_line_plot
#     df_robust[column] = (df_robust[column] - df_robust[column].median())  / (df_robust[column].quantile(0.75) - df_robust[column].quantile(0.25))
#   File "/shared-libs/python3.9/py/lib/python3.9/site-packages/pandas/core/frame.py", line 3024, in __getitem__
#     indexer = self.columns.get_loc(key)
#   File "/shared-libs/python3.9/py/lib/python3.9/site-packages/pandas/core/indexes/base.py", line 3081, in get_loc
#     return self._engine.get_loc(casted_key)
#   File "pandas/_libs/index.pyx", line 70, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas/_libs/index.pyx", line 96, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas/_libs/index.pyx", line 109, in pandas._libs.index.IndexEngine._get_loc_duplicates
#   File "pandas/_libs/index.pyx", line 176, in pandas._libs.index.IndexEngine.is_monotonic_increasing.__get__
#   File "pandas/_libs/index.pyx", line 193, in pandas._libs.index.IndexEngine._do_monotonic_check
#   File "pandas/_libs/index.pyx", line 210, in pandas._libs.index.IndexEngine._call_monotonic
#   File "pandas/_libs/algos.pyx", line 760, in pandas._libs.algos.is_monotonic
#   File "/shared-libs/python3.9/py/lib/python3.9/site-packages/pandas/core/generic.py", line 1442, in __nonzero__
#     raise ValueError(
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
#     raise TypeError(
# TypeError: 'Series' objects are mutable, thus they cannot be hashed
# 172.3.22.214 - - [03/May/2023 09:14:08] "POST /_dash-update-component HTTP/1.1" 500 -
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File pandas/_libs/hashtable_class_helper.pxi:4588, in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# File /shared-libs/python3.9/py/lib/python3.9/site-packages/pandas/core/generic.py:1785, in NDFrame.__hash__(self)
#    1784 def __hash__(self) -> int:
# -> 1785     raise TypeError(
#    1786         f"{repr(type(self).__name__)} objects are mutable, "
#    1787         f"thus they cannot be hashed"
#    1788     )
#
# TypeError: 'Series' objects are mutable, thus they cannot be hashed
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas/_libs/hashtable_class_helper.pxi", line 4588, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# [2023-05-03 09:14:08,886] ERROR in app: Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/root/venv/lib/python3.9/site-packages/flask/app.py", line 2190, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/root/venv/lib/python3.9/site-packages/flask/app.py", line 1486, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/root/venv/lib/python3.9/site-packages/flask/app.py", line 1484, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/root/venv/lib/python3.9/site-packages/flask/app.py", line 1469, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#   File "/root/venv/lib/python3.9/site-packages/dash/dash.py", line 1283, in dispatch
#     ctx.run(
#   File "/root/venv/lib/python3.9/site-packages/dash/_callback.py", line 450, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "/tmp/ipykernel_127/1041133795.py", line 162, in update_pair_plot
#     df_robust[column] = (df_robust[column] - df_robust[column].median())  / (df_robust[column].quantile(0.75) - df_robust[column].quantile(0.25))
#   File "/shared-libs/python3.9/py/lib/python3.9/site-packages/pandas/core/frame.py", line 3024, in __getitem__
#     indexer = self.columns.get_loc(key)
#   File "/shared-libs/python3.9/py/lib/python3.9/site-packages/pandas/core/indexes/base.py", line 3081, in get_loc
#     return self._engine.get_loc(casted_key)
#   File "pandas/_libs/index.pyx", line 70, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas/_libs/index.pyx", line 96, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas/_libs/index.pyx", line 109, in pandas._libs.index.IndexEngine._get_loc_duplicates
#   File "pandas/_libs/index.pyx", line 176, in pandas._libs.index.IndexEngine.is_monotonic_increasing.__get__
#   File "pandas/_libs/index.pyx", line 193, in pandas._libs.index.IndexEngine._do_monotonic_check
#   File "pandas/_libs/index.pyx", line 210, in pandas._libs.index.IndexEngine._call_monotonic
#   File "pandas/_libs/algos.pyx", line 760, in pandas._libs.algos.is_monotonic
#   File "/shared-libs/python3.9/py/lib/python3.9/site-packages/pandas/core/generic.py", line 1442, in __nonzero__
#     raise ValueError(
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# 172.3.22.214 - - [03/May/2023 09:14:08] "POST /_dash-update-component HTTP/1.1" 500 -
#   File "/shared-libs/python3.9/py/lib/python3.9/site-packages/pandas/core/generic.py", line 1785, in __hash__
#     raise TypeError(
# TypeError: 'Series' objects are mutable, thus they cannot be hashed
# [2023-05-03 09:14:08,891] ERROR in app: Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/root/venv/lib/python3.9/site-packages/flask/app.py", line 2190, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/root/venv/lib/python3.9/site-packages/flask/app.py", line 1486, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/root/venv/lib/python3.9/site-packages/flask/app.py", line 1484, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/root/venv/lib/python3.9/site-packages/flask/app.py", line 1469, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#   File "/root/venv/lib/python3.9/site-packages/dash/dash.py", line 1283, in dispatch
#     ctx.run(
#   File "/root/venv/lib/python3.9/site-packages/dash/_callback.py", line 450, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "/tmp/ipykernel_127/1041133795.py", line 211, in update_time_series_decomposition_plot
#     df_robust[column] = (df_robust[column] - df_robust[column].median())  / (df_robust[column].quantile(0.75) - df_robust[column].quantile(0.25))
#   File "/shared-libs/python3.9/py/lib/python3.9/site-packages/pandas/core/frame.py", line 3024, in __getitem__
#     indexer = self.columns.get_loc(key)
#   File "/shared-libs/python3.9/py/lib/python3.9/site-packages/pandas/core/indexes/base.py", line 3081, in get_loc
#     return self._engine.get_loc(casted_key)
#   File "pandas/_libs/index.pyx", line 70, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas/_libs/index.pyx", line 96, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas/_libs/index.pyx", line 109, in pandas._libs.index.IndexEngine._get_loc_duplicates
#   File "pandas/_libs/index.pyx", line 176, in pandas._libs.index.IndexEngine.is_monotonic_increasing.__get__
#   File "pandas/_libs/index.pyx", line 193, in pandas._libs.index.IndexEngine._do_monotonic_check
#   File "pandas/_libs/index.pyx", line 210, in pandas._libs.index.IndexEngine._call_monotonic
#   File "pandas/_libs/algos.pyx", line 760, in pandas._libs.algos.is_monotonic
#   File "/shared-libs/python3.9/py/lib/python3.9/site-packages/pandas/core/generic.py", line 1442, in __nonzero__
#     raise ValueError(
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# 172.3.18.60 - - [03/May/2023 09:14:08] "POST /_dash-update-component HTTP/1.1" 500 -

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=638889fe-2546-41ac-8d2f-f9d8b29d307c' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
